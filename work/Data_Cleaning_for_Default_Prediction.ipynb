# %%
# %pip install kagglehub
# %pip install pandas scikit-learn matplotlib seaborn
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /home/codespace/.local/lib/python3.12/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from kagglehub) (2.32.5)
# Collecting tqdm (from kagglehub)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting protobuf (from kagglesdk<1.0,>=0.1.14->kagglehub)
#   Downloading protobuf-7.34.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->kagglehub) (2025.11.12)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.16-py3-none-any.whl (160 kB)
# Downloading protobuf-7.34.1-cp310-abi3-manylinux2014_x86_64.whl (324 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, protobuf, kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [kagglehub]/4 [kagglehub]
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.16 protobuf-7.34.1 tqdm-4.67.3
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 38.9 MB/s  0:00:006m0:00:01
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 15.2 MB/s  0:00:006m0:00:01
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 17.3 MB/s  0:00:00m0:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 50.9 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.7 MB/s  0:00:00
# Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 19.4 MB/s  0:00:006m0:00:01
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 42.5 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 43.3 MB/s  0:00:006m0:00:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [seaborn]3/14 [seaborn]ib]n]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 joblib-1.5.3 kiwisolver-1.5.0 matplotlib-3.10.8 numpy-2.4.3 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import pandas as pd
import os

path = kagglehub.dataset_download("adarshsng/lending-club-loan-data-csv")
csv_path = os.path.join(path, "loan.csv")

# Only load the first 1.4 million rows (out of 2.26 million)
#loan_df = pd.read_csv(csv_path, nrows=1400000)

# retreive all column names
cols = pd.read_csv(csv_path, nrows=0).columns

# column to be dropped, comments are missing percentage
cols_to_drop = ['id',   # 100%
                'member_id',   # 100%
                'url',   # 100%
                'desc',   # 94%
                'mths_since_last_delinq',  # 51%
                'mths_since_last_record',  # 84%
                'next_pymnt_d',   # 58%
                'mths_since_last_major_derog',   # 74%
                'annual_inc_joint',   # 95%
                'dti_joint',   # 95%
                'verification_status_joint',   # 95%
                'open_acc_6m',   # 38%
                'open_act_il',   # 38%
                'open_il_12m',   # 38%
                'open_il_24m',   # 38%
                'mths_since_rcnt_il',   # 40%
                #'total_bal_il',   # 38%
                #'il_util',   # 47%
                'open_rv_12m',   # 38%
                'open_rv_24m',   # 38%
                'max_bal_bc',   # 38%
                #'all_util',   # 38%
                'inq_fi',   # 38%
                'total_cu_tl',   # 38%
                #'inq_last_12m',   # 38%
                'mths_since_recent_bc_dlq',  # 77%
                'mths_since_recent_revol_delinq',  # 67%
                'revol_bal_joint',  # 95%
                'sec_app_earliest_cr_line',  # 95%
                'sec_app_inq_last_6mths',   # 95%
                'sec_app_mort_acc',   # 95%
                'sec_app_open_acc',   # 95%
                'sec_app_revol_util',   # 95%
                'sec_app_open_act_il',  # 95%
                'sec_app_num_rev_accts',  # 95%
                'sec_app_chargeoff_within_12_mths',   # 95%
                'sec_app_collections_12_mths_ex_med',   # 95%
                'sec_app_mths_since_last_major_derog',  # 98%
                'hardship_type',   # 100%
                'hardship_reason',  # 100%
                'hardship_status',  # 100%
                'deferral_term',   # 100%
                'hardship_amount',  # 100%
                'hardship_start_date',  # 100%
                'hardship_end_date',   # 100%
                'payment_plan_start_date',   # 100%
                'hardship_length',   # 100%
                'hardship_dpd',  # 100%
                'hardship_loan_status',   # 100%
                'orig_projected_additional_accrued_interest',  # 100%
                'hardship_payoff_balance_amount',   # 100%
                'hardship_last_payment_amount',   # 100%
                'debt_settlement_flag_date',   # 99%
                'settlement_status',   # 99%
                'settlement_date',   # 99%
                'settlement_amount',   # 99%
                'settlement_percentage',   # 99%
                'settlement_term',  # 99%
                
                # Variables irrelevant for default prediction
                #'collection_recovery_fee',
                #'recoveries',
                'last_credit_pull_d',
                'last_pymnt_amnt',
                'last_pymnt_d',
                'out_prncp',
                'out_prncp_inv',
                'total_pymnt',
                'total_pymnt_inv',
                'total_rec_int',
                'total_rec_late_fee',
                #'total_rec_prncp',

                # add more irrelevant columns (by Kasem)
                'policy_code',
                'tot_coll_amt',
                #'total_rev_hi_lim',  # correlated with revol_util
                #'avg_cur_bal',
                #'bc_open_to_buy',
                'mo_sin_old_il_acct',
                'mo_sin_rcnt_rev_tl_op',
                'mo_sin_rcnt_tl',
                'mths_since_recent_inq',
                'num_actv_bc_tl',

                #ashish
                'funded_amnt',      # post-application, leakage
                'funded_amnt_inv',  # post-application, leakage
                #'installment',      # derived from loan_amnt + int_rate + term, redundant
                'grade',            # multicollinesrity with sub-grade
                'issue_d',          # will not be available at prediction time
                'pymnt_plan',       # post-default indicator, pure leakage
                'title',            # free-text, redundant with purpose
                'zip_code',         # redundant with addr_state, too granular
                
                #prerna
                'hardship_flag',         # Post-loan hardship event (data leakage)
                'debt_settlement_flag',  # Post-default outcome indicator (data leakage)
                'disbursement_method',   # Operational variable, not related to credit risk
                'num_sats',              # Raw count; percentage version is more informative
                'num_bc_tl',             # Weak standalone signal; redundant with other credit counts
                'num_il_tl',             # Installment count adds little predictive value
                'num_op_rev_tl',         # Highly correlated with other account count variables
                'num_rev_accts',         # Redundant credit depth measure
                'total_bc_limit'         # Redundant with overall credit limit (tot_hi_cred_lim)
                ]

# columns to keep
cols_to_keep = [col for col in cols if col not in cols_to_drop]

# load data
loan_df = pd.read_csv(csv_path, usecols=cols_to_keep)

# %%
# create index column
loan_df['index'] = loan_df.index

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Data columns (total 60 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   loan_amnt                   int64
#  1   term                        object
#  2   int_rate                    float64
#  3   installment                 float64
#  4   sub_grade                   object
#  5   emp_title                   object
#  6   emp_length                  object
#  7   home_ownership              object
#  8   annual_inc                  float64
#  9   verification_status         object
#  10  loan_status                 object
#  11  purpose                     object
#  12  addr_state                  object
#  13  dti                         float64
#  14  delinq_2yrs                 float64
#  15  earliest_cr_line            object
#  16  inq_last_6mths              float64
#  17  open_acc                    float64
#  18  pub_rec                     float64
#  19  revol_bal                   int64
#  20  revol_util                  float64
#  21  total_acc                   float64
#  22  initial_list_status         object
#  23  total_rec_prncp             float64
#  24  recoveries                  float64
#  25  collection_recovery_fee     float64
#  26  collections_12_mths_ex_med  float64
#  27  application_type            object
#  28  acc_now_delinq              float64
#  29  tot_cur_bal                 float64
#  30  total_bal_il                float64
#  31  il_util                     float64
#  32  all_util                    float64
#  33  total_rev_hi_lim            float64
#  34  inq_last_12m                float64
#  35  acc_open_past_24mths        float64
#  36  avg_cur_bal                 float64
#  37  bc_open_to_buy              float64
#  38  bc_util                     float64
#  39  chargeoff_within_12_mths    float64
#  40  delinq_amnt                 float64
#  41  mo_sin_old_rev_tl_op        float64
#  42  mort_acc                    float64
#  43  mths_since_recent_bc        float64
#  44  num_accts_ever_120_pd       float64
#  45  num_actv_rev_tl             float64
#  46  num_bc_sats                 float64
#  47  num_rev_tl_bal_gt_0         float64
#  48  num_tl_120dpd_2m            float64
#  49  num_tl_30dpd                float64
#  50  num_tl_90g_dpd_24m          float64
#  51  num_tl_op_past_12m          float64
#  52  pct_tl_nvr_dlq              float64
#  53  percent_bc_gt_75            float64
#  54  pub_rec_bankruptcies        float64
#  55  tax_liens                   float64
#  56  tot_hi_cred_lim             float64
#  57  total_bal_ex_mort           float64
#  58  total_il_high_credit_limit  float64
#  59  index                       int64
# dtypes: float64(45), int64(3), object(12)
# memory usage: 1.0+ GB

# %%
# Check for columns with large amount of missing values
missing = loan_df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(ascending=False)
# Out:
# il_util                       1068850
# all_util                       866348
# inq_last_12m                   866130
# total_bal_il                   866129
# emp_title                      166969
# num_tl_120dpd_2m               153657
# emp_length                     146907
# bc_util                         76071
# percent_bc_gt_75                75379
# bc_open_to_buy                  74935
# mths_since_recent_bc            73412
# pct_tl_nvr_dlq                  70431
# avg_cur_bal                     70346
# mo_sin_old_rev_tl_op            70277
# total_il_high_credit_limit      70276
# tot_cur_bal                     70276
# tot_hi_cred_lim                 70276
# num_tl_op_past_12m              70276
# total_rev_hi_lim                70276
# num_tl_90g_dpd_24m              70276
# num_tl_30dpd                    70276
# num_rev_tl_bal_gt_0             70276
# num_actv_rev_tl                 70276
# num_accts_ever_120_pd           70276
# num_bc_sats                     58590
# total_bal_ex_mort               50030
# mort_acc                        50030
# acc_open_past_24mths            50030
# revol_util                       1802
# dti                              1711
# pub_rec_bankruptcies             1365
# collections_12_mths_ex_med        145
# chargeoff_within_12_mths          145
# tax_liens                         105
# inq_last_6mths                     30
# delinq_amnt                        29
# delinq_2yrs                        29
# earliest_cr_line                   29
# open_acc                           29
# pub_rec                            29
# acc_now_delinq                     29
# total_acc                          29
# annual_inc                          4
# dtype: int64

# %%
# change string cols to categorical type

# list of column names to change to categorical type
to_cat_list = ['application_type', 'home_ownership', 'verification_status', 
               'purpose', 'initial_list_status']
loan_df[to_cat_list] = loan_df[to_cat_list].astype('category')

# %%
# change cols to numeric dtype
loan_df['term'] = loan_df['term'].str.strip().str.replace(' months', '').astype(int)
emp_length_map = {
    '< 1 year': 0,
    '1 year': 1, '2 years': 2, '3 years': 3, '4 years': 4,
    '5 years': 5, '6 years': 6, '7 years': 7, '8 years': 8,
    '9 years': 9, '10+ years': 10
}
loan_df['emp_length'] = loan_df['emp_length'].map(emp_length_map)
loan_df['emp_length'] = loan_df['emp_length'].fillna(loan_df['emp_length'].median())

# Create new binary variable for employment based on employment title
loan_df["Employed"] = loan_df["emp_title"].notna().astype(int)
loan_df["emp_title"] = loan_df["emp_title"].fillna("Unemployed")

# Convert to credit age in years
from datetime import datetime
loan_df['earliest_cr_line'] = pd.to_datetime(loan_df['earliest_cr_line'], format='%b-%Y')
loan_df['credit_age_years'] = (pd.Timestamp.now() - loan_df['earliest_cr_line']).dt.days / 365
loan_df.drop('earliest_cr_line', axis=1, inplace=True)

# %%
loan_df["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid                                             1041952
# Current                                                 919695
# Charged Off                                             261655
# Late (31-120 days)                                       21897
# In Grace Period                                           8952
# Late (16-30 days)                                         3737
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     31
# Name: count, dtype: int64

# %%
small_null_cols = [col for col in loan_df.columns if 0 < loan_df[col].isnull().sum() <= 2000]
print(small_null_cols)

loan_df = loan_df.dropna(subset=small_null_cols)
print(loan_df.shape)
# Out:
# ['annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_util', 'total_acc', 'collections_12_mths_ex_med', 'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens', 'credit_age_years']
# (2255820, 61)

# %%
# plot histogram for all numerical columns
import matplotlib.pyplot as plt


cols = loan_df.select_dtypes(include='number').columns
batch_size = 9  # 3x3 grid per figure

for i in range(0, len(cols), batch_size):
    batch = cols[i:i+batch_size]
    loan_df[batch].hist(figsize=(12, 8), bins=30)
    plt.tight_layout()
    plt.show()

# %%
# Check outlier inc annually income -- imp factor while lending
print(loan_df['annual_inc'].describe())
print(loan_df['annual_inc'].quantile(0.999))

# Cap at 99.9th percentile
cap = loan_df['annual_inc'].quantile(0.999)
loan_df['annual_inc'] = loan_df['annual_inc'].clip(upper=cap)
# Out:
# count    2.255820e+06
# mean     7.804968e+04
# std      1.127283e+05
# min      0.000000e+00
# 25%      4.600000e+04
# 50%      6.500000e+04
# 75%      9.300000e+04
# max      1.100000e+08
# Name: annual_inc, dtype: float64
# 600000.0

# %%
# heatmap for correlation
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(loan_df.select_dtypes('number').corr(), cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
# correlation table
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
loan_df.select_dtypes('number').corr()
# Out:
#                             loan_amnt      term  int_rate  installment  \
# loan_amnt                    1.000000  0.393707  0.098187     0.945597
# term                         0.393707  1.000000  0.372711     0.139007
# int_rate                     0.098187  0.372711  1.000000     0.124009
# installment                  0.945597  0.139007  0.124009     1.000000
# emp_length                   0.076278  0.053495 -0.009609     0.063624
# annual_inc                   0.423920  0.078049 -0.106355     0.409413
# dti                          0.043339  0.058125  0.124772     0.044673
# delinq_2yrs                 -0.009180 -0.009132  0.058817     0.002161
# inq_last_6mths              -0.027218 -0.000676  0.189861    -0.001726
# open_acc                     0.182183  0.074688 -0.010162     0.171410
# pub_rec                     -0.058977 -0.017659  0.053506    -0.047209
# revol_bal                    0.317310  0.083394 -0.028722     0.303329
# revol_util                   0.099134  0.067266  0.262559     0.120984
# total_acc                    0.199655  0.095760 -0.040800     0.178415
# total_rec_prncp              0.578352  0.085969 -0.026473     0.597500
# recoveries                   0.121139  0.108235  0.145043     0.119013
# collection_recovery_fee      0.116146  0.101077  0.134616     0.114335
# collections_12_mths_ex_med  -0.021891 -0.009940  0.018336    -0.017512
# acc_now_delinq              -0.000517 -0.000038  0.015566     0.002135
# tot_cur_bal                  0.310470  0.111081 -0.085546     0.277661
# total_bal_il                 0.150682  0.081732  0.035310     0.138837
# il_util                     -0.088004  0.022610  0.143990    -0.081379
# all_util                     0.002824  0.047812  0.289949     0.028551
# total_rev_hi_lim             0.328658  0.069089 -0.181654     0.297866
# inq_last_12m                 0.009383  0.024359  0.166327     0.026137
# acc_open_past_24mths        -0.000962  0.026246  0.172428     0.017550
# avg_cur_bal                  0.227815  0.084166 -0.083728     0.199602
# bc_open_to_buy               0.205408  0.015239 -0.297285     0.167840
# bc_util                      0.048399  0.051414  0.277094     0.074082
# chargeoff_within_12_mths    -0.003787 -0.002230  0.014184    -0.001034
# delinq_amnt                  0.000814 -0.000897  0.004854     0.001955
# mo_sin_old_rev_tl_op         0.165557  0.047691 -0.133578     0.141652
# mort_acc                     0.219145  0.102998 -0.090003     0.184471
# mths_since_recent_bc         0.036324  0.021005 -0.075505     0.018298
# num_accts_ever_120_pd       -0.053487 -0.018773  0.051768    -0.043110
# num_actv_rev_tl              0.149117  0.055570  0.082859     0.156072
# num_bc_sats                  0.212476  0.049460 -0.060868     0.204663
# num_rev_tl_bal_gt_0          0.148492  0.055882  0.082741     0.155189
# num_tl_120dpd_2m            -0.001808 -0.001690  0.006077    -0.000422
# num_tl_30dpd                 0.000915  0.000648  0.012771     0.002986
# num_tl_90g_dpd_24m          -0.023502 -0.011019  0.033398    -0.017052
# num_tl_op_past_12m          -0.026831  0.006933  0.182081    -0.004193
# pct_tl_nvr_dlq               0.089420  0.042818 -0.079232     0.070350
# percent_bc_gt_75             0.020824  0.047633  0.271852     0.044023
# pub_rec_bankruptcies        -0.083698 -0.011675  0.056812    -0.075195
# tax_liens                    0.007516 -0.009024  0.013936     0.014280
# tot_hi_cred_lim              0.335273  0.108622 -0.123947     0.299225
# total_bal_ex_mort            0.276459  0.107230  0.007090     0.258580
# total_il_high_credit_limit   0.208666  0.091745 -0.001588     0.191308
# index                       -0.048171 -0.006994  0.058744    -0.037413
# Employed                     0.074734  0.049535 -0.004014     0.065156
# credit_age_years             0.142073  0.044653 -0.103110     0.122588
#
#                             emp_length  annual_inc       dti  delinq_2yrs  \
# loan_amnt                     0.076278    0.423920  0.043339    -0.009180
# term                          0.053495    0.078049  0.058125    -0.009132
# int_rate                     -0.009609   -0.106355  0.124772     0.058817
# installment                   0.063624    0.409413  0.044673     0.002161
# emp_length                    1.000000    0.088810  0.014629     0.021915
# annual_inc                    0.088810    1.000000 -0.164588     0.056509
# dti                           0.014629   -0.164588  1.000000    -0.012242
# delinq_2yrs                   0.021915    0.056509 -0.012242     1.000000
# inq_last_6mths               -0.000458    0.043872 -0.011787     0.024567
# open_acc                      0.051099    0.205046  0.186268     0.049175
# pub_rec                       0.030535   -0.005926 -0.026205    -0.021810
# revol_bal                     0.085098    0.393449  0.102500    -0.026702
# revol_util                    0.035403    0.061540  0.115122    -0.000190
# total_acc                     0.104361    0.250225  0.147298     0.118574
# total_rec_prncp               0.073646    0.292838 -0.028945     0.007038
# recoveries                    0.010743    0.022439  0.021091     0.016339
# collection_recovery_fee       0.010537    0.022589  0.021912     0.016744
# collections_12_mths_ex_med   -0.006411   -0.006681 -0.007085     0.071977
# acc_now_delinq                0.008512    0.015656 -0.000169     0.116008
# tot_cur_bal                   0.097495    0.533395  0.021360     0.056519
# total_bal_il                 -0.041950    0.297481  0.155481     0.045489
# il_util                      -0.095496   -0.058069 -0.012728    -0.007895
# all_util                     -0.048612    0.025745  0.124230     0.023991
# total_rev_hi_lim              0.084529    0.389111  0.061459    -0.047910
# inq_last_12m                 -0.005950    0.099862  0.025104     0.029406
# acc_open_past_24mths          0.023481    0.087404  0.084503    -0.050223
# avg_cur_bal                   0.081882    0.401329 -0.056011     0.045356
# bc_open_to_buy                0.026986    0.221695 -0.036011    -0.060346
# bc_util                       0.031023    0.011486  0.117817     0.002884
# chargeoff_within_12_mths      0.009152    0.010366 -0.003360     0.140040
# delinq_amnt                   0.001794    0.008506 -0.003698     0.028496
# mo_sin_old_rev_tl_op          0.193115    0.186828  0.041188     0.078816
# mort_acc                      0.180294    0.293162 -0.009563     0.075226
# mths_since_recent_bc          0.037354    0.028381  0.002914     0.052770
# num_accts_ever_120_pd         0.009023    0.019320 -0.029265     0.218139
# num_actv_rev_tl               0.121608    0.124897  0.159217    -0.000167
# num_bc_sats                   0.069192    0.189526  0.071227    -0.030860
# num_rev_tl_bal_gt_0           0.122540    0.123013  0.161545    -0.004347
# num_tl_120dpd_2m              0.001797    0.006114 -0.003325     0.043986
# num_tl_30dpd                  0.007990    0.014410  0.001232     0.097845
# num_tl_90g_dpd_24m           -0.001275    0.009104 -0.013378     0.656816
# num_tl_op_past_12m            0.023055    0.074668  0.045208    -0.022029
# pct_tl_nvr_dlq               -0.019211   -0.009833  0.065470    -0.442479
# percent_bc_gt_75              0.028540   -0.006660  0.104021    -0.000523
# pub_rec_bankruptcies          0.023622   -0.059468 -0.012457    -0.049291
# tax_liens                     0.014957    0.052976 -0.020587     0.011375
# tot_hi_cred_lim               0.112462    0.557601  0.031386     0.056689
# total_bal_ex_mort            -0.009716    0.438880  0.194358     0.028154
# total_il_high_credit_limit   -0.025982    0.377516  0.219885     0.056490
# index                         0.003307   -0.031453 -0.040678     0.011712
# Employed                      0.025909    0.123460 -0.060232     0.020787
# credit_age_years              0.201850    0.179968  0.027236     0.083393
#
#                             inq_last_6mths  open_acc   pub_rec  revol_bal  \
# loan_amnt                        -0.027218  0.182183 -0.058977   0.317310
# term                             -0.000676  0.074688 -0.017659   0.083394
# int_rate                          0.189861 -0.010162  0.053506  -0.028722
# installment                      -0.001726  0.171410 -0.047209   0.303329
# emp_length                       -0.000458  0.051099  0.030535   0.085098
# annual_inc                        0.043872  0.205046 -0.005926   0.393449
# dti                              -0.011787  0.186268 -0.026205   0.102500
# delinq_2yrs                       0.024567  0.049175 -0.021810  -0.026702
# inq_last_6mths                    1.000000  0.139045  0.065507  -0.010297
# open_acc                          0.139045  1.000000 -0.015277   0.237302
# pub_rec                           0.065507 -0.015277  1.000000  -0.085923
# revol_bal                        -0.010297  0.237302 -0.085923   1.000000
# revol_util                       -0.078902 -0.134839 -0.051873   0.245244
# total_acc                         0.156079  0.717889  0.003577   0.204867
# total_rec_prncp                   0.013394  0.116200 -0.027121   0.224064
# recoveries                        0.051491  0.032764  0.007794   0.021963
# collection_recovery_fee           0.046010  0.033388  0.009228   0.021584
# collections_12_mths_ex_med        0.011416  0.007845  0.009855  -0.024811
# acc_now_delinq                   -0.001407  0.016898  0.000795   0.000994
# tot_cur_bal                       0.030595  0.256705 -0.062995   0.439303
# total_bal_il                      0.060386  0.349098 -0.016871   0.101601
# il_util                           0.086580  0.128284  0.023425  -0.095120
# all_util                         -0.035306 -0.005794 -0.001997   0.120216
# total_rev_hi_lim                  0.020700  0.397524 -0.098107   0.803662
# inq_last_12m                      0.477395  0.183036  0.086050  -0.025402
# acc_open_past_24mths              0.280359  0.493771  0.095167  -0.011166
# avg_cur_bal                      -0.023521 -0.104867 -0.049695   0.279005
# bc_open_to_buy                    0.014482  0.312713 -0.084655   0.165396
# bc_util                          -0.069399 -0.097588 -0.020810   0.178364
# chargeoff_within_12_mths          0.011968  0.006400 -0.005019  -0.010376
# delinq_amnt                       0.001511  0.003132  0.004133   0.003880
# mo_sin_old_rev_tl_op             -0.004278  0.145584  0.038261   0.229612
# mort_acc                          0.046837  0.134653 -0.011460   0.213694
# mths_since_recent_bc             -0.130420 -0.209610 -0.047141   0.026559
# num_accts_ever_120_pd             0.049511  0.023441  0.011672  -0.078328
# num_actv_rev_tl                   0.127490  0.672511  0.001020   0.315691
# num_bc_sats                       0.123879  0.640680 -0.036969   0.285221
# num_rev_tl_bal_gt_0               0.109307  0.674676 -0.003147   0.314970
# num_tl_120dpd_2m                  0.000941  0.004186  0.003123  -0.003095
# num_tl_30dpd                     -0.003234  0.014917 -0.003413   0.004279
# num_tl_90g_dpd_24m                0.030109  0.010861 -0.003556  -0.032569
# num_tl_op_past_12m                0.330340  0.371557  0.082890  -0.024043
# pct_tl_nvr_dlq                   -0.028355  0.110111 -0.009045   0.113794
# percent_bc_gt_75                 -0.061976 -0.087888 -0.030523   0.142571
# pub_rec_bankruptcies              0.074086 -0.016811  0.659238  -0.109223
# tax_liens                         0.013960 -0.005291  0.697925  -0.009530
# tot_hi_cred_lim                   0.031275  0.298719 -0.070472   0.465758
# total_bal_ex_mort                 0.037245  0.406217 -0.054661   0.507011
# total_il_high_credit_limit        0.044349  0.368763 -0.023902   0.138500
# index                             0.098809 -0.022335  0.008599  -0.006155
# Employed                          0.009402  0.066662 -0.031522   0.034099
# credit_age_years                  0.028160  0.139343  0.057546   0.211920
#
#                             revol_util  total_acc  total_rec_prncp  \
# loan_amnt                     0.099134   0.199655         0.578352
# term                          0.067266   0.095760         0.085969
# int_rate                      0.262559  -0.040800        -0.026473
# installment                   0.120984   0.178415         0.597500
# emp_length                    0.035403   0.104361         0.073646
# annual_inc                    0.061540   0.250225         0.292838
# dti                           0.115122   0.147298        -0.028945
# delinq_2yrs                  -0.000190   0.118574         0.007038
# inq_last_6mths               -0.078902   0.156079         0.013394
# open_acc                     -0.134839   0.717889         0.116200
# pub_rec                      -0.051873   0.003577        -0.027121
# revol_bal                     0.245244   0.204867         0.224064
# revol_util                    1.000000  -0.093320         0.114212
# total_acc                    -0.093320   1.000000         0.185411
# total_rec_prncp               0.114212   0.185411         1.000000
# recoveries                    0.050043   0.044390        -0.107571
# collection_recovery_fee       0.046176   0.044036        -0.099726
# collections_12_mths_ex_med   -0.034919   0.005564        -0.021237
# acc_now_delinq               -0.020269   0.025669         0.012731
# tot_cur_bal                   0.088311   0.322907         0.228193
# total_bal_il                  0.031005   0.421574         0.082843
# il_util                      -0.067332   0.116891        -0.035673
# all_util                      0.668152   0.008478         0.017915
# total_rev_hi_lim             -0.134702   0.319768         0.207734
# inq_last_12m                 -0.127803   0.215173         0.025087
# acc_open_past_24mths         -0.220776   0.433774        -0.014645
# avg_cur_bal                   0.131582   0.056080         0.177219
# bc_open_to_buy               -0.483640   0.238801         0.100897
# bc_util                       0.868536  -0.069666         0.082993
# chargeoff_within_12_mths     -0.010943   0.040973         0.001372
# delinq_amnt                  -0.004250   0.005734         0.003118
# mo_sin_old_rev_tl_op          0.021998   0.280960         0.145342
# mort_acc                      0.038347   0.368069         0.222002
# mths_since_recent_bc          0.144997  -0.125368         0.026545
# num_accts_ever_120_pd        -0.020159   0.147029        -0.034392
# num_actv_rev_tl               0.109851   0.417527         0.096440
# num_bc_sats                  -0.121093   0.413978         0.133243
# num_rev_tl_bal_gt_0           0.116168   0.418181         0.096835
# num_tl_120dpd_2m             -0.008331   0.009605         0.004490
# num_tl_30dpd                 -0.015084   0.020449         0.012384
# num_tl_90g_dpd_24m           -0.004817   0.068681        -0.009046
# num_tl_op_past_12m           -0.215304   0.333542        -0.025831
# pct_tl_nvr_dlq               -0.030214   0.020968         0.058625
# percent_bc_gt_75              0.739605  -0.056261         0.060501
# pub_rec_bankruptcies         -0.073878   0.022805        -0.068497
# tax_liens                    -0.002857  -0.015241         0.023932
# tot_hi_cred_lim               0.029799   0.349117         0.237816
# total_bal_ex_mort             0.126396   0.440310         0.166631
# total_il_high_credit_limit    0.035854   0.427051         0.106167
# index                         0.107011   0.038176         0.253541
# Employed                      0.048174   0.044157         0.091613
# credit_age_years              0.061619   0.284717         0.206641
#
#                             recoveries  collection_recovery_fee  \
# loan_amnt                     0.121139                 0.116146
# term                          0.108235                 0.101077
# int_rate                      0.145043                 0.134616
# installment                   0.119013                 0.114335
# emp_length                    0.010743                 0.010537
# annual_inc                    0.022439                 0.022589
# dti                           0.021091                 0.021912
# delinq_2yrs                   0.016339                 0.016744
# inq_last_6mths                0.051491                 0.046010
# open_acc                      0.032764                 0.033388
# pub_rec                       0.007794                 0.009228
# revol_bal                     0.021963                 0.021584
# revol_util                    0.050043                 0.046176
# total_acc                     0.044390                 0.044036
# total_rec_prncp              -0.107571                -0.099726
# recoveries                    1.000000                 0.969235
# collection_recovery_fee       0.969235                 1.000000
# collections_12_mths_ex_med    0.002136                 0.002718
# acc_now_delinq                0.006875                 0.006525
# tot_cur_bal                   0.009314                 0.009792
# total_bal_il                  0.021885                 0.021521
# il_util                       0.026555                 0.026044
# all_util                      0.041332                 0.041084
# total_rev_hi_lim             -0.000426                 0.000548
# inq_last_12m                  0.043623                 0.042924
# acc_open_past_24mths          0.060046                 0.059674
# avg_cur_bal                  -0.002384                -0.002386
# bc_open_to_buy               -0.031213                -0.029372
# bc_util                       0.048799                 0.045788
# chargeoff_within_12_mths      0.003127                 0.003421
# delinq_amnt                   0.001689                 0.001708
# mo_sin_old_rev_tl_op         -0.000220                 0.001047
# mort_acc                      0.015941                 0.015561
# mths_since_recent_bc         -0.024090                -0.023366
# num_accts_ever_120_pd         0.003877                 0.004690
# num_actv_rev_tl               0.040081                 0.040008
# num_bc_sats                   0.019470                 0.019659
# num_rev_tl_bal_gt_0           0.039659                 0.039459
# num_tl_120dpd_2m              0.001911                 0.001894
# num_tl_30dpd                  0.005630                 0.005212
# num_tl_90g_dpd_24m            0.005620                 0.005782
# num_tl_op_past_12m            0.051463                 0.050964
# pct_tl_nvr_dlq                0.001196                 0.000178
# percent_bc_gt_75              0.048034                 0.044821
# pub_rec_bankruptcies          0.001792                 0.003271
# tax_liens                     0.006302                 0.006715
# tot_hi_cred_lim               0.005213                 0.006012
# total_bal_ex_mort             0.029425                 0.030381
# total_il_high_credit_limit    0.023292                 0.024500
# index                         0.054413                 0.042771
# Employed                      0.013141                 0.012585
# credit_age_years              0.022185                 0.020394
#
#                             collections_12_mths_ex_med  acc_now_delinq  \
# loan_amnt                                    -0.021891       -0.000517
# term                                         -0.009940       -0.000038
# int_rate                                      0.018336        0.015566
# installment                                  -0.017512        0.002135
# emp_length                                   -0.006411        0.008512
# annual_inc                                   -0.006681        0.015656
# dti                                          -0.007085       -0.000169
# delinq_2yrs                                   0.071977        0.116008
# inq_last_6mths                                0.011416       -0.001407
# open_acc                                      0.007845        0.016898
# pub_rec                                       0.009855        0.000795
# revol_bal                                    -0.024811        0.000994
# revol_util                                   -0.034919       -0.020269
# total_acc                                     0.005564        0.025669
# total_rec_prncp                              -0.021237        0.012731
# recoveries                                    0.002136        0.006875
# collection_recovery_fee                       0.002718        0.006525
# collections_12_mths_ex_med                    1.000000        0.020787
# acc_now_delinq                                0.020787        1.000000
# tot_cur_bal                                  -0.013195        0.020011
# total_bal_il                                 -0.002956        0.004575
# il_util                                       0.002847       -0.008503
# all_util                                     -0.016393       -0.014441
# total_rev_hi_lim                             -0.021756        0.008039
# inq_last_12m                                  0.015483       -0.002207
# acc_open_past_24mths                          0.015750       -0.003252
# avg_cur_bal                                  -0.014479        0.013851
# bc_open_to_buy                               -0.015477        0.008765
# bc_util                                      -0.030481       -0.019054
# chargeoff_within_12_mths                      0.043734        0.037630
# delinq_amnt                                   0.006617        0.170383
# mo_sin_old_rev_tl_op                         -0.009429        0.025560
# mort_acc                                     -0.013210        0.023472
# mths_since_recent_bc                         -0.008534        0.008272
# num_accts_ever_120_pd                         0.048272        0.020460
# num_actv_rev_tl                               0.005614        0.001852
# num_bc_sats                                   0.001172       -0.002967
# num_rev_tl_bal_gt_0                          -0.002040        0.001316
# num_tl_120dpd_2m                              0.003199        0.391467
# num_tl_30dpd                                  0.000353        0.801694
# num_tl_90g_dpd_24m                            0.107488        0.054638
# num_tl_op_past_12m                            0.013389       -0.004849
# pct_tl_nvr_dlq                               -0.047966       -0.043616
# percent_bc_gt_75                             -0.031366       -0.016470
# pub_rec_bankruptcies                         -0.003745       -0.008814
# tax_liens                                     0.010729        0.007877
# tot_hi_cred_lim                              -0.012948        0.023236
# total_bal_ex_mort                            -0.013319        0.006962
# total_il_high_credit_limit                   -0.001876        0.012193
# index                                        -0.011724        0.010307
# Employed                                      0.002039        0.004353
# credit_age_years                             -0.001163        0.028079
#
#                             tot_cur_bal  total_bal_il   il_util  all_util  \
# loan_amnt                      0.310470      0.150682 -0.088004  0.002824
# term                           0.111081      0.081732  0.022610  0.047812
# int_rate                      -0.085546      0.035310  0.143990  0.289949
# installment                    0.277661      0.138837 -0.081379  0.028551
# emp_length                     0.097495     -0.041950 -0.095496 -0.048612
# annual_inc                     0.533395      0.297481 -0.058069  0.025745
# dti                            0.021360      0.155481 -0.012728  0.124230
# delinq_2yrs                    0.056519      0.045489 -0.007895  0.023991
# inq_last_6mths                 0.030595      0.060386  0.086580 -0.035306
# open_acc                       0.256705      0.349098  0.128284 -0.005794
# pub_rec                       -0.062995     -0.016871  0.023425 -0.001997
# revol_bal                      0.439303      0.101601 -0.095120  0.120216
# revol_util                     0.088311      0.031005 -0.067332  0.668152
# total_acc                      0.322907      0.421574  0.116891  0.008478
# total_rec_prncp                0.228193      0.082843 -0.035673  0.017915
# recoveries                     0.009314      0.021885  0.026555  0.041332
# collection_recovery_fee        0.009792      0.021521  0.026044  0.041084
# collections_12_mths_ex_med    -0.013195     -0.002956  0.002847 -0.016393
# acc_now_delinq                 0.020011      0.004575 -0.008503 -0.014441
# tot_cur_bal                    1.000000      0.405054  0.044723  0.104168
# total_bal_il                   0.405054      1.000000  0.317344  0.284731
# il_util                        0.044723      0.317344  1.000000  0.561239
# all_util                       0.104168      0.284731  0.561239  1.000000
# total_rev_hi_lim               0.400016      0.109290 -0.093815 -0.226123
# inq_last_12m                   0.130908      0.156809  0.176121  0.030896
# acc_open_past_24mths           0.111985      0.195014  0.223240 -0.040050
# avg_cur_bal                    0.832316      0.212920  0.002502  0.102665
# bc_open_to_buy                 0.164370      0.054000 -0.052033 -0.470154
# bc_util                        0.047689      0.022215 -0.056104  0.606305
# chargeoff_within_12_mths       0.005171      0.002252 -0.001956 -0.005122
# delinq_amnt                    0.018276     -0.000405 -0.005379 -0.001895
# mo_sin_old_rev_tl_op           0.186150      0.019750 -0.100403 -0.069300
# mort_acc                       0.541933      0.102679 -0.036501 -0.009454
# mths_since_recent_bc           0.044525     -0.003580 -0.050920  0.096191
# num_accts_ever_120_pd          0.015093      0.071449  0.094018  0.082421
# num_actv_rev_tl                0.105192      0.040985 -0.056540 -0.008384
# num_bc_sats                    0.124783      0.050210 -0.058833 -0.198853
# num_rev_tl_bal_gt_0            0.104692      0.042400 -0.054821  0.001750
# num_tl_120dpd_2m               0.006375      0.000909 -0.002086 -0.002419
# num_tl_30dpd                   0.019776      0.002833 -0.010248 -0.013545
# num_tl_90g_dpd_24m             0.007646      0.035743  0.030178  0.033819
# num_tl_op_past_12m             0.097441      0.156639  0.229152 -0.041787
# pct_tl_nvr_dlq                 0.010835      0.008287 -0.031862 -0.082925
# percent_bc_gt_75               0.037831      0.017653 -0.051962  0.502965
# pub_rec_bankruptcies          -0.090026     -0.024374  0.025873 -0.015125
# tax_liens                     -0.000548      0.002457  0.000976  0.004880
# tot_hi_cred_lim                0.975517      0.375446 -0.006547  0.022833
# total_bal_ex_mort              0.530915      0.900603  0.230832  0.291430
# total_il_high_credit_limit     0.427821      0.952190  0.168606  0.223009
# index                         -0.006357      0.000348 -0.005983  0.025120
# Employed                       0.074968      0.109829  0.037250  0.093590
# credit_age_years               0.179445      0.041595 -0.075477 -0.032015
#
#                             total_rev_hi_lim  inq_last_12m  \
# loan_amnt                           0.328658      0.009383
# term                                0.069089      0.024359
# int_rate                           -0.181654      0.166327
# installment                         0.297866      0.026137
# emp_length                          0.084529     -0.005950
# annual_inc                          0.389111      0.099862
# dti                                 0.061459      0.025104
# delinq_2yrs                        -0.047910      0.029406
# inq_last_6mths                      0.020700      0.477395
# open_acc                            0.397524      0.183036
# pub_rec                            -0.098107      0.086050
# revol_bal                           0.803662     -0.025402
# revol_util                         -0.134702     -0.127803
# total_acc                           0.319768      0.215173
# total_rec_prncp                     0.207734      0.025087
# recoveries                         -0.000426      0.043623
# collection_recovery_fee             0.000548      0.042924
# collections_12_mths_ex_med         -0.021756      0.015483
# acc_now_delinq                      0.008039     -0.002207
# tot_cur_bal                         0.400016      0.130908
# total_bal_il                        0.109290      0.156809
# il_util                            -0.093815      0.176121
# all_util                           -0.226123      0.030896
# total_rev_hi_lim                    1.000000      0.022928
# inq_last_12m                        0.022928      1.000000
# acc_open_past_24mths                0.111581      0.405570
# avg_cur_bal                         0.195254      0.058652
# bc_open_to_buy                      0.618744      0.031206
# bc_util                            -0.175149     -0.112937
# chargeoff_within_12_mths           -0.011598      0.011004
# delinq_amnt                         0.002976     -0.000251
# mo_sin_old_rev_tl_op                0.265391     -0.040929
# mort_acc                            0.223175      0.109247
# mths_since_recent_bc               -0.054407     -0.129008
# num_accts_ever_120_pd              -0.099837      0.079681
# num_actv_rev_tl                     0.342178      0.087107
# num_bc_sats                         0.471347      0.099444
# num_rev_tl_bal_gt_0                 0.340476      0.084841
# num_tl_120dpd_2m                   -0.000838     -0.000845
# num_tl_30dpd                        0.010017     -0.003402
# num_tl_90g_dpd_24m                 -0.045737      0.018603
# num_tl_op_past_12m                  0.084859      0.464266
# pct_tl_nvr_dlq                      0.173825     -0.025668
# percent_bc_gt_75                   -0.146579     -0.107713
# pub_rec_bankruptcies               -0.115150      0.096979
# tax_liens                          -0.018045      0.021617
# tot_hi_cred_lim                     0.491443      0.122088
# total_bal_ex_mort                   0.430273      0.121451
# total_il_high_credit_limit          0.142500      0.145000
# index                              -0.049488      0.005536
# Employed                            0.015656      0.028683
# credit_age_years                    0.224999     -0.023225
#
#                             acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  \
# loan_amnt                              -0.000962     0.227815        0.205408
# term                                    0.026246     0.084166        0.015239
# int_rate                                0.172428    -0.083728       -0.297285
# installment                             0.017550     0.199602        0.167840
# emp_length                              0.023481     0.081882        0.026986
# annual_inc                              0.087404     0.401329        0.221695
# dti                                     0.084503    -0.056011       -0.036011
# delinq_2yrs                            -0.050223     0.045356       -0.060346
# inq_last_6mths                          0.280359    -0.023521        0.014482
# open_acc                                0.493771    -0.104867        0.312713
# pub_rec                                 0.095167    -0.049695       -0.084655
# revol_bal                              -0.011166     0.279005        0.165396
# revol_util                             -0.220776     0.131582       -0.483640
# total_acc                               0.433774     0.056080        0.238801
# total_rec_prncp                        -0.014645     0.177219        0.100897
# recoveries                              0.060046    -0.002384       -0.031213
# collection_recovery_fee                 0.059674    -0.002386       -0.029372
# collections_12_mths_ex_med              0.015750    -0.014479       -0.015477
# acc_now_delinq                         -0.003252     0.013851        0.008765
# tot_cur_bal                             0.111985     0.832316        0.164370
# total_bal_il                            0.195014     0.212920        0.054000
# il_util                                 0.223240     0.002502       -0.052033
# all_util                               -0.040050     0.102665       -0.470154
# total_rev_hi_lim                        0.111581     0.195254        0.618744
# inq_last_12m                            0.405570     0.058652        0.031206
# acc_open_past_24mths                    1.000000    -0.066312        0.127456
# avg_cur_bal                            -0.066312     1.000000        0.033631
# bc_open_to_buy                          0.127456     0.033631        1.000000
# bc_util                                -0.176740     0.076756       -0.541945
# chargeoff_within_12_mths                0.005372     0.005549       -0.010792
# delinq_amnt                            -0.001987     0.016463        0.000263
# mo_sin_old_rev_tl_op                   -0.055516     0.128316        0.176766
# mort_acc                                0.072641     0.466618        0.122329
# mths_since_recent_bc                   -0.341792     0.152514       -0.122249
# num_accts_ever_120_pd                   0.074830     0.019448       -0.085876
# num_actv_rev_tl                         0.344393    -0.150508        0.122805
# num_bc_sats                             0.313596    -0.119058        0.490603
# num_rev_tl_bal_gt_0                     0.338325    -0.152069        0.134901
# num_tl_120dpd_2m                       -0.002849     0.005264        0.000747
# num_tl_30dpd                           -0.004212     0.013982        0.008415
# num_tl_90g_dpd_24m                     -0.028518     0.010537       -0.043964
# num_tl_op_past_12m                      0.764703    -0.039727        0.113107
# pct_tl_nvr_dlq                          0.056592    -0.049599        0.165630
# percent_bc_gt_75                       -0.162791     0.067753       -0.440071
# pub_rec_bankruptcies                    0.113767    -0.075575       -0.093031
# tax_liens                               0.016097     0.003445       -0.020303
# tot_hi_cred_lim                         0.119672     0.791696        0.269153
# total_bal_ex_mort                       0.160394     0.297441        0.120940
# total_il_high_credit_limit              0.186454     0.221583        0.079394
# index                                  -0.023457     0.001842       -0.084198
# Employed                                0.031625     0.051029       -0.009029
# credit_age_years                       -0.038411     0.125237        0.126197
#
#                              bc_util  chargeoff_within_12_mths  delinq_amnt  \
# loan_amnt                   0.048399                 -0.003787     0.000814
# term                        0.051414                 -0.002230    -0.000897
# int_rate                    0.277094                  0.014184     0.004854
# installment                 0.074082                 -0.001034     0.001955
# emp_length                  0.031023                  0.009152     0.001794
# annual_inc                  0.011486                  0.010366     0.008506
# dti                         0.117817                 -0.003360    -0.003698
# delinq_2yrs                 0.002884                  0.140040     0.028496
# inq_last_6mths             -0.069399                  0.011968     0.001511
# open_acc                   -0.097588                  0.006400     0.003132
# pub_rec                    -0.020810                 -0.005019     0.004133
# revol_bal                   0.178364                 -0.010376     0.003880
# revol_util                  0.868536                 -0.010943    -0.004250
# total_acc                  -0.069666                  0.040973     0.005734
# total_rec_prncp             0.082993                  0.001372     0.003118
# recoveries                  0.048799                  0.003127     0.001689
# collection_recovery_fee     0.045788                  0.003421     0.001708
# collections_12_mths_ex_med -0.030481                  0.043734     0.006617
# acc_now_delinq             -0.019054                  0.037630     0.170383
# tot_cur_bal                 0.047689                  0.005171     0.018276
# total_bal_il                0.022215                  0.002252    -0.000405
# il_util                    -0.056104                 -0.001956    -0.005379
# all_util                    0.606305                 -0.005122    -0.001895
# total_rev_hi_lim           -0.175149                 -0.011598     0.002976
# inq_last_12m               -0.112937                  0.011004    -0.000251
# acc_open_past_24mths       -0.176740                  0.005372    -0.001987
# avg_cur_bal                 0.076756                  0.005549     0.016463
# bc_open_to_buy             -0.541945                 -0.010792     0.000263
# bc_util                     1.000000                 -0.009610    -0.004498
# chargeoff_within_12_mths   -0.009610                  1.000000     0.010877
# delinq_amnt                -0.004498                  0.010877     1.000000
# mo_sin_old_rev_tl_op        0.009172                  0.031260     0.007018
# mort_acc                    0.017279                  0.027836     0.012751
# mths_since_recent_bc        0.149999                  0.005540     0.002999
# num_accts_ever_120_pd      -0.014575                  0.119049     0.017457
# num_actv_rev_tl             0.126320                  0.000770     0.001342
# num_bc_sats                -0.173601                 -0.003178     0.001555
# num_rev_tl_bal_gt_0         0.130821                 -0.001707    -0.000226
# num_tl_120dpd_2m           -0.007136                  0.037533     0.320861
# num_tl_30dpd               -0.014021                  0.000707     0.043040
# num_tl_90g_dpd_24m         -0.005436                  0.209543     0.038994
# num_tl_op_past_12m         -0.186555                  0.002704    -0.001833
# pct_tl_nvr_dlq             -0.031459                 -0.082983    -0.012929
# percent_bc_gt_75            0.846754                 -0.009205    -0.004672
# pub_rec_bankruptcies       -0.029336                 -0.011002    -0.001088
# tax_liens                  -0.002223                 -0.000972     0.005314
# tot_hi_cred_lim            -0.010068                  0.005743     0.017755
# total_bal_ex_mort           0.090756                 -0.002897     0.002632
# total_il_high_credit_limit  0.021705                  0.004520     0.001618
# index                       0.115079                  0.002225     0.000585
# Employed                    0.039387                 -0.003961     0.001053
# credit_age_years            0.051950                  0.029760     0.007801
#
#                             mo_sin_old_rev_tl_op  mort_acc  \
# loan_amnt                               0.165557  0.219145
# term                                    0.047691  0.102998
# int_rate                               -0.133578 -0.090003
# installment                             0.141652  0.184471
# emp_length                              0.193115  0.180294
# annual_inc                              0.186828  0.293162
# dti                                     0.041188 -0.009563
# delinq_2yrs                             0.078816  0.075226
# inq_last_6mths                         -0.004278  0.046837
# open_acc                                0.145584  0.134653
# pub_rec                                 0.038261 -0.011460
# revol_bal                               0.229612  0.213694
# revol_util                              0.021998  0.038347
# total_acc                               0.280960  0.368069
# total_rec_prncp                         0.145342  0.222002
# recoveries                             -0.000220  0.015941
# collection_recovery_fee                 0.001047  0.015561
# collections_12_mths_ex_med             -0.009429 -0.013210
# acc_now_delinq                          0.025560  0.023472
# tot_cur_bal                             0.186150  0.541933
# total_bal_il                            0.019750  0.102679
# il_util                                -0.100403 -0.036501
# all_util                               -0.069300 -0.009454
# total_rev_hi_lim                        0.265391  0.223175
# inq_last_12m                           -0.040929  0.109247
# acc_open_past_24mths                   -0.055516  0.072641
# avg_cur_bal                             0.128316  0.466618
# bc_open_to_buy                          0.176766  0.122329
# bc_util                                 0.009172  0.017279
# chargeoff_within_12_mths                0.031260  0.027836
# delinq_amnt                             0.007018  0.012751
# mo_sin_old_rev_tl_op                    1.000000  0.290080
# mort_acc                                0.290080  1.000000
# mths_since_recent_bc                    0.129126  0.054691
# num_accts_ever_120_pd                   0.069250  0.057679
# num_actv_rev_tl                         0.163458  0.061199
# num_bc_sats                             0.161240  0.073213
# num_rev_tl_bal_gt_0                     0.160984  0.059782
# num_tl_120dpd_2m                        0.007319  0.010390
# num_tl_30dpd                            0.023465  0.020286
# num_tl_90g_dpd_24m                      0.027806  0.028456
# num_tl_op_past_12m                     -0.026400  0.065517
# pct_tl_nvr_dlq                         -0.081063 -0.032143
# percent_bc_gt_75                        0.023875  0.017545
# pub_rec_bankruptcies                    0.034552 -0.008969
# tax_liens                               0.019667 -0.008143
# tot_hi_cred_lim                         0.218344  0.544667
# total_bal_ex_mort                       0.114774  0.162753
# total_il_high_credit_limit              0.039664  0.122782
# index                                   0.023552  0.055375
# Employed                               -0.145341 -0.004683
# credit_age_years                        0.901586  0.295818
#
#                             mths_since_recent_bc  num_accts_ever_120_pd  \
# loan_amnt                               0.036324              -0.053487
# term                                    0.021005              -0.018773
# int_rate                               -0.075505               0.051768
# installment                             0.018298              -0.043110
# emp_length                              0.037354               0.009023
# annual_inc                              0.028381               0.019320
# dti                                     0.002914              -0.029265
# delinq_2yrs                             0.052770               0.218139
# inq_last_6mths                         -0.130420               0.049511
# open_acc                               -0.209610               0.023441
# pub_rec                                -0.047141               0.011672
# revol_bal                               0.026559              -0.078328
# revol_util                              0.144997              -0.020159
# total_acc                              -0.125368               0.147029
# total_rec_prncp                         0.026545              -0.034392
# recoveries                             -0.024090               0.003877
# collection_recovery_fee                -0.023366               0.004690
# collections_12_mths_ex_med             -0.008534               0.048272
# acc_now_delinq                          0.008272               0.020460
# tot_cur_bal                             0.044525               0.015093
# total_bal_il                           -0.003580               0.071449
# il_util                                -0.050920               0.094018
# all_util                                0.096191               0.082421
# total_rev_hi_lim                       -0.054407              -0.099837
# inq_last_12m                           -0.129008               0.079681
# acc_open_past_24mths                   -0.341792               0.074830
# avg_cur_bal                             0.152514               0.019448
# bc_open_to_buy                         -0.122249              -0.085876
# bc_util                                 0.149999              -0.014575
# chargeoff_within_12_mths                0.005540               0.119049
# delinq_amnt                             0.002999               0.017457
# mo_sin_old_rev_tl_op                    0.129126               0.069250
# mort_acc                                0.054691               0.057679
# mths_since_recent_bc                    1.000000              -0.015179
# num_accts_ever_120_pd                  -0.015179               1.000000
# num_actv_rev_tl                        -0.209299              -0.027574
# num_bc_sats                            -0.290932              -0.067222
# num_rev_tl_bal_gt_0                    -0.207072              -0.022243
# num_tl_120dpd_2m                        0.005046               0.031527
# num_tl_30dpd                            0.007018              -0.002586
# num_tl_90g_dpd_24m                      0.024602               0.311307
# num_tl_op_past_12m                     -0.308656               0.082646
# pct_tl_nvr_dlq                         -0.053384              -0.578719
# percent_bc_gt_75                        0.153107              -0.021683
# pub_rec_bankruptcies                   -0.063836              -0.032028
# tax_liens                              -0.000968               0.011961
# tot_hi_cred_lim                         0.034052               0.004580
# total_bal_ex_mort                       0.015164               0.020045
# total_il_high_credit_limit              0.007679               0.046939
# index                                  -0.003027              -0.006017
# Employed                               -0.018050               0.001108
# credit_age_years                        0.110483               0.083527
#
#                             num_actv_rev_tl  num_bc_sats  num_rev_tl_bal_gt_0  \
# loan_amnt                          0.149117     0.212476             0.148492
# term                               0.055570     0.049460             0.055882
# int_rate                           0.082859    -0.060868             0.082741
# installment                        0.156072     0.204663             0.155189
# emp_length                         0.121608     0.069192             0.122540
# annual_inc                         0.124897     0.189526             0.123013
# dti                                0.159217     0.071227             0.161545
# delinq_2yrs                       -0.000167    -0.030860            -0.004347
# inq_last_6mths                     0.127490     0.123879             0.109307
# open_acc                           0.672511     0.640680             0.674676
# pub_rec                            0.001020    -0.036969            -0.003147
# revol_bal                          0.315691     0.285221             0.314970
# revol_util                         0.109851    -0.121093             0.116168
# total_acc                          0.417527     0.413978             0.418181
# total_rec_prncp                    0.096440     0.133243             0.096835
# recoveries                         0.040081     0.019470             0.039659
# collection_recovery_fee            0.040008     0.019659             0.039459
# collections_12_mths_ex_med         0.005614     0.001172            -0.002040
# ...
# pct_tl_nvr_dlq                       -0.263663            0.009678
# percent_bc_gt_75                     -0.007042           -0.171738
# pub_rec_bankruptcies                 -0.012490            0.092131
# tax_liens                             0.002246            0.017464
# tot_hi_cred_lim                       0.003921            0.101293
# total_bal_ex_mort                     0.014355            0.119261
# total_il_high_credit_limit            0.029534            0.137542
# index                                 0.010990           -0.025580
# Employed                              0.006468            0.021357
# credit_age_years                      0.037239           -0.012471
#
#                             pct_tl_nvr_dlq  percent_bc_gt_75  \
# loan_amnt                         0.089420          0.020824
# term                              0.042818          0.047633
# int_rate                         -0.079232          0.271852
# installment                       0.070350          0.044023
# emp_length                       -0.019211          0.028540
# annual_inc                       -0.009833         -0.006660
# dti                               0.065470          0.104021
# delinq_2yrs                      -0.442479         -0.000523
# inq_last_6mths                   -0.028355         -0.061976
# open_acc                          0.110111         -0.087888
# pub_rec                          -0.009045         -0.030523
# revol_bal                         0.113794          0.142571
# revol_util                       -0.030214          0.739605
# total_acc                         0.020968         -0.056261
# total_rec_prncp                   0.058625          0.060501
# recoveries                        0.001196          0.048034
# collection_recovery_fee           0.000178          0.044821
# collections_12_mths_ex_med       -0.047966         -0.031366
# acc_now_delinq                   -0.043616         -0.016470
# tot_cur_bal                       0.010835          0.037831
# total_bal_il                      0.008287          0.017653
# il_util                          -0.031862         -0.051962
# all_util                         -0.082925          0.502965
# total_rev_hi_lim                  0.173825         -0.146579
# inq_last_12m                     -0.025668         -0.107713
# acc_open_past_24mths              0.056592         -0.162791
# avg_cur_bal                      -0.049599          0.067753
# bc_open_to_buy                    0.165630         -0.440071
# bc_util                          -0.031459          0.846754
# chargeoff_within_12_mths         -0.082983         -0.009205
# delinq_amnt                      -0.012929         -0.004672
# mo_sin_old_rev_tl_op             -0.081063          0.023875
# mort_acc                         -0.032143          0.017545
# mths_since_recent_bc             -0.053384          0.153107
# num_accts_ever_120_pd            -0.578719         -0.021683
# num_actv_rev_tl                   0.095864          0.095420
# num_bc_sats                       0.145252         -0.161989
# num_rev_tl_bal_gt_0               0.102851          0.099891
# num_tl_120dpd_2m                 -0.017200         -0.007380
# num_tl_30dpd                     -0.036365         -0.011989
# num_tl_90g_dpd_24m               -0.263663         -0.007042
# num_tl_op_past_12m                0.009678         -0.171738
# pct_tl_nvr_dlq                    1.000000         -0.015090
# percent_bc_gt_75                 -0.015090          1.000000
# pub_rec_bankruptcies              0.050561         -0.033971
# tax_liens                        -0.032278         -0.009914
# tot_hi_cred_lim                   0.024357         -0.009244
# total_bal_ex_mort                 0.061511          0.070303
# total_il_high_credit_limit        0.018939          0.014955
# index                            -0.000592          0.111759
# Employed                         -0.008832          0.031869
# credit_age_years                 -0.094591          0.061003
#
#                             pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# loan_amnt                              -0.083698   0.007516         0.335273
# term                                   -0.011675  -0.009024         0.108622
# int_rate                                0.056812   0.013936        -0.123947
# installment                            -0.075195   0.014280         0.299225
# emp_length                              0.023622   0.014957         0.112462
# annual_inc                             -0.059468   0.052976         0.557601
# dti                                    -0.012457  -0.020587         0.031386
# delinq_2yrs                            -0.049291   0.011375         0.056689
# inq_last_6mths                          0.074086   0.013960         0.031275
# open_acc                               -0.016811  -0.005291         0.298719
# pub_rec                                 0.659238   0.697925        -0.070472
# revol_bal                              -0.109223  -0.009530         0.465758
# revol_util                             -0.073878  -0.002857         0.029799
# total_acc                               0.022805  -0.015241         0.349117
# total_rec_prncp                        -0.068497   0.023932         0.237816
# recoveries                              0.001792   0.006302         0.005213
# collection_recovery_fee                 0.003271   0.006715         0.006012
# collections_12_mths_ex_med             -0.003745   0.010729        -0.012948
# acc_now_delinq                         -0.008814   0.007877         0.023236
# tot_cur_bal                            -0.090026  -0.000548         0.975517
# total_bal_il                           -0.024374   0.002457         0.375446
# il_util                                 0.025873   0.000976        -0.006547
# all_util                               -0.015125   0.004880         0.022833
# total_rev_hi_lim                       -0.115150  -0.018045         0.491443
# inq_last_12m                            0.096979   0.021617         0.122088
# acc_open_past_24mths                    0.113767   0.016097         0.119672
# avg_cur_bal                            -0.075575   0.003445         0.791696
# bc_open_to_buy                         -0.093031  -0.020303         0.269153
# bc_util                                -0.029336  -0.002223        -0.010068
# chargeoff_within_12_mths               -0.011002  -0.000972         0.005743
# delinq_amnt                            -0.001088   0.005314         0.017755
# mo_sin_old_rev_tl_op                    0.034552   0.019667         0.218344
# mort_acc                               -0.008969  -0.008143         0.544667
# mths_since_recent_bc                   -0.063836  -0.000968         0.034052
# num_accts_ever_120_pd                  -0.032028   0.011961         0.004580
# num_actv_rev_tl                        -0.009586   0.007512         0.134247
# num_bc_sats                            -0.052674   0.001905         0.182966
# num_rev_tl_bal_gt_0                    -0.015752   0.008029         0.133730
# num_tl_120dpd_2m                       -0.001464   0.004138         0.006688
# num_tl_30dpd                           -0.011666   0.005765         0.022964
# num_tl_90g_dpd_24m                     -0.012490   0.002246         0.003921
# num_tl_op_past_12m                      0.092131   0.017464         0.101293
# pct_tl_nvr_dlq                          0.050561  -0.032278         0.024357
# percent_bc_gt_75                       -0.033971  -0.009914        -0.009244
# pub_rec_bankruptcies                    1.000000   0.033049        -0.100939
# tax_liens                               0.033049   1.000000        -0.000115
# tot_hi_cred_lim                        -0.100939  -0.000115         1.000000
# total_bal_ex_mort                      -0.073263  -0.001073         0.520133
# total_il_high_credit_limit             -0.035902   0.005319         0.425492
# index                                  -0.011166   0.016127        -0.018644
# Employed                               -0.045757  -0.002837         0.069821
# credit_age_years                        0.040561   0.035411         0.204563
#
#                             total_bal_ex_mort  total_il_high_credit_limit  \
# loan_amnt                            0.276459                    0.208666
# term                                 0.107230                    0.091745
# int_rate                             0.007090                   -0.001588
# installment                          0.258580                    0.191308
# emp_length                          -0.009716                   -0.025982
# annual_inc                           0.438880                    0.377516
# dti                                  0.194358                    0.219885
# delinq_2yrs                          0.028154                    0.056490
# inq_last_6mths                       0.037245                    0.044349
# open_acc                             0.406217                    0.368763
# pub_rec                             -0.054661                   -0.023902
# revol_bal                            0.507011                    0.138500
# revol_util                           0.126396                    0.035854
# total_acc                            0.440310                    0.427051
# total_rec_prncp                      0.166631                    0.106167
# recoveries                           0.029425                    0.023292
# collection_recovery_fee              0.030381                    0.024500
# collections_12_mths_ex_med          -0.013319                   -0.001876
# acc_now_delinq                       0.006962                    0.012193
# tot_cur_bal                          0.530915                    0.427821
# total_bal_il                         0.900603                    0.952190
# il_util                              0.230832                    0.168606
# all_util                             0.291430                    0.223009
# total_rev_hi_lim                     0.430273                    0.142500
# inq_last_12m                         0.121451                    0.145000
# acc_open_past_24mths                 0.160394                    0.186454
# avg_cur_bal                          0.297441                    0.221583
# bc_open_to_buy                       0.120940                    0.079394
# bc_util                              0.090756                    0.021705
# chargeoff_within_12_mths            -0.002897                    0.004520
# delinq_amnt                          0.002632                    0.001618
# mo_sin_old_rev_tl_op                 0.114774                    0.039664
# mort_acc                             0.162753                    0.122782
# mths_since_recent_bc                 0.015164                    0.007679
# num_accts_ever_120_pd                0.020045                    0.046939
# num_actv_rev_tl                      0.161098                    0.043359
# num_bc_sats                          0.156993                    0.060520
# num_rev_tl_bal_gt_0                  0.164268                    0.044972
# num_tl_120dpd_2m                     0.001799                    0.003556
# num_tl_30dpd                         0.006817                    0.010837
# num_tl_90g_dpd_24m                   0.014355                    0.029534
# num_tl_op_past_12m                   0.119261                    0.137542
# pct_tl_nvr_dlq                       0.061511                    0.018939
# percent_bc_gt_75                     0.070303                    0.014955
# pub_rec_bankruptcies                -0.073263                   -0.035902
# tax_liens                           -0.001073                    0.005319
# tot_hi_cred_lim                      0.520133                    0.425492
# total_bal_ex_mort                    1.000000                    0.877544
# total_il_high_credit_limit           0.877544                    1.000000
# index                               -0.029133                   -0.037982
# Employed                             0.102424                    0.112693
# credit_age_years                     0.118418                    0.045746
#
#                                index  Employed  credit_age_years
# loan_amnt                  -0.048171  0.074734          0.142073
# term                       -0.006994  0.049535          0.044653
# int_rate                    0.058744 -0.004014         -0.103110
# installment                -0.037413  0.065156          0.122588
# emp_length                  0.003307  0.025909          0.201850
# annual_inc                 -0.031453  0.123460          0.179968
# dti                        -0.040678 -0.060232          0.027236
# delinq_2yrs                 0.011712  0.020787          0.083393
# inq_last_6mths              0.098809  0.009402          0.028160
# open_acc                   -0.022335  0.066662          0.139343
# pub_rec                     0.008599 -0.031522          0.057546
# revol_bal                  -0.006155  0.034099          0.211920
# revol_util                  0.107011  0.048174          0.061619
# total_acc                   0.038176  0.044157          0.284717
# total_rec_prncp             0.253541  0.091613          0.206641
# recoveries                  0.054413  0.013141          0.022185
# collection_recovery_fee     0.042771  0.012585          0.020394
# collections_12_mths_ex_med -0.011724  0.002039         -0.001163
# acc_now_delinq              0.010307  0.004353          0.028079
# tot_cur_bal                -0.006357  0.074968          0.179445
# total_bal_il                0.000348  0.109829          0.041595
# il_util                    -0.005983  0.037250         -0.075477
# all_util                    0.025120  0.093590         -0.032015
# total_rev_hi_lim           -0.049488  0.015656          0.224999
# inq_last_12m                0.005536  0.028683         -0.023225
# acc_open_past_24mths       -0.023457  0.031625         -0.038411
# avg_cur_bal                 0.001842  0.051029          0.125237
# bc_open_to_buy             -0.084198 -0.009029          0.126197
# bc_util                     0.115079  0.039387          0.051950
# chargeoff_within_12_mths    0.002225 -0.003961          0.029760
# delinq_amnt                 0.000585  0.001053          0.007801
# mo_sin_old_rev_tl_op        0.023552 -0.145341          0.901586
# mort_acc                    0.055375 -0.004683          0.295818
# mths_since_recent_bc       -0.003027 -0.018050          0.110483
# num_accts_ever_120_pd      -0.006017  0.001108          0.083527
# num_actv_rev_tl             0.018432  0.011007          0.161582
# num_bc_sats                -0.015965  0.017340          0.136935
# num_rev_tl_bal_gt_0         0.018532  0.010421          0.160342
# num_tl_120dpd_2m            0.006022  0.001337          0.009516
# num_tl_30dpd                0.010370  0.004883          0.025268
# num_tl_90g_dpd_24m          0.010990  0.006468          0.037239
# num_tl_op_past_12m         -0.025580  0.021357         -0.012471
# pct_tl_nvr_dlq             -0.000592 -0.008832         -0.094591
# percent_bc_gt_75            0.111759  0.031869          0.061003
# pub_rec_bankruptcies       -0.011166 -0.045757          0.040561
# tax_liens                   0.016127 -0.002837          0.035411
# tot_hi_cred_lim            -0.018644  0.069821          0.204563
# total_bal_ex_mort          -0.029133  0.102424          0.118418
# total_il_high_credit_limit -0.037982  0.112693          0.045746
# index                       1.000000  0.054319          0.138347
# Employed                    0.054319  1.000000         -0.135476
# credit_age_years            0.138347 -0.135476          1.000000

# %%
# save file
#loan_df.to_csv('loan_data.csv', index=False)

# csv file link
# https://drive.google.com/file/d/1ewIyvaTB1T_BVNM5CYNTXrIpPv9kJjK3/view?usp=sharing

# %%
# The following drive has cleaned loan_default dataset
# https://drive.google.com/drive/folders/1O-em9ZJIMIjs-PXUTE1hzbpjNUhYRsW2?usp=sharing
